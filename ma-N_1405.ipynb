# %%
# %matplotlib inline

import IPython
import matplotlib.pyplot as plt 
import matplotlib

import numpy as np

import math as m

# %% [markdown]
# ### NB01, 1 and 2um wires

# %%
x = [250, 255, 260, 265, 275, 350]
y = [980, 986, 1020, 1030, 1100, 1150]
y2 = [2188, 2200, 2260, 2280, 2330, 2440]

fig = plt.figure()

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) 

axes.plot(x, y, label='1um')
axes.plot(x, y2, label='2um')
axes.grid(True)
axes.legend()

# %% [markdown]
# ### L01, C03, f=1/6 (...001)

# %%
x = [60+i*5 for i in range(6, 12)]
# L01, C03, f=1/6 (...001)
y = [
    np.average([818, 818, 782, 800]),
    np.average([931, 990, 941, 931]),
    np.average([994, 1021, 1007, 1101]),
    np.average([1166, 1156, 1124]),
    np.average([1199, 1172, 1226, 1185]),
    np.average([1233, 1193, 1220, 1206])
]
y2 = [2188, 2200, 2260, 2280, 2330, 2440]


fig = plt.figure()

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) 

axes.plot(x, y, label='1um')
# axes.plot(x, y2, label='2um')
axes.grid(True)
axes.legend()
